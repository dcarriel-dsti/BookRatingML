# %% [markdown]
# # Book Rating ML Predictor

# %%
import pandas as pd
import os

class ExcelFileReader:
    """
    A class for reading Excel files in a specified directory.
    """

    def __init__(self, directory: str) -> None:
        """
        Initializes the ExcelFileReader with the directory path.

        Parameters:
        - directory: The path to the directory containing the Excel files.
        """
        self.directory = directory

    def load_excel_files(self) -> None:
        
        
    def print_excel_files(self) -> None:
        """
        Reads all of the Excel files in the specified directory and prints their contents to the console.
        """
        for file in os.listdir(self.directory):
            if file.endswith(".xlsx"):
                filepath = os.path.join(self.directory, file)
                df = pd.read_excel(filepath)
                print(df)
                
    def get_dataframe(self)-> DataFrame: 
        return self.dataframe

# %%
os.getcwd()
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'BookRatingML.ipynb',
#  'data set without modification.csv',
#  'LICENSE',
#  'Project_Description_ML_2023.docx (2).pdf',
#  'Projet Python retravaillé.xlsx',
#  'Projet Python simulations.xlsx',
#  'README.md',
#  'Summary and to do list.xlsx',
#  '~$Projet Python retravaillé.xlsx',
#  '~$Projet Python simulations.xlsx',
#  '~$Summary and to do list.xlsx']

# %%
data = pd.read_csv('books.csv', on_bad_lines='skip')

# %%
data
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
data = pd.read_csv('data set without modification.csv', delimiter=";", encoding_errors='ignore')

# %%
data
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           1  Harry Potter and the Order of the Phoenix (Har...
# 2           1  Harry Potter and the Chamber of Secrets (Harry...
# 3           1  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           1  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122       1   Expelled from Eden: A William T. Vollmann Reader
# 11123       1                        You Bright and Risen Angels
# 11124       1                    The Ice-Shirt (Seven Dreams #1)
# 11125       1                                        Poor People
# 11126       1                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                              J.K. Rowling/Mary GrandPr           4,57
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  int64
#  1   title               11127 non-null  object
#  2   authors             11127 non-null  object
#  3   average_rating      11127 non-null  object
#  4   isbn                11127 non-null  object
#  5   isbn13              11126 non-null  object
#  6   language_code       11127 non-null  object
#  7   num_pages           11123 non-null  float64
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  Colonne1            11127 non-null  int64
#  11  publication_date    11127 non-null  object
#  12  publisher           11127 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#         bookID     num_pages  ratings_count  text_reviews_count      Colonne1
# count  11127.0  11123.000000   1.112700e+04        11127.000000  1.112700e+04
# mean       1.0    336.405556   1.793649e+04          541.864474  1.739463e+04
# std        0.0    241.152626   1.124794e+05         2576.174610  1.102560e+05
# min        1.0      0.000000   0.000000e+00            0.000000 -1.000000e+00
# 25%        1.0    192.000000   1.040000e+02            9.000000  9.400000e+01
# 50%        1.0    299.000000   7.450000e+02           47.000000  6.870000e+02
# 75%        1.0    416.000000   4.993500e+03          237.500000  4.724000e+03
# max        1.0   6576.000000   4.597666e+06        94265.000000  4.503401e+06

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 10.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 965.4/965.4 kB 15.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 161.3/161.3 kB 9.4 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ---------------------------------------- 2.5/2.5 MB 12.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 5.9 MB/s eta 0:00:00
# ...
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
df.corr()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_24620\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       bookID  average_rating    isbn13    num_pages  \
# bookID              1.000000       -0.036207 -0.002185    -0.026134
# average_rating     -0.036207        1.000000 -0.001965     0.150477
# isbn13             -0.002185       -0.001965  1.000000    -0.009818
#   num_pages        -0.026134        0.150477 -0.009818     1.000000
# ratings_count      -0.076820        0.038224  0.005494     0.034337
# text_reviews_count -0.081289        0.033663  0.008152     0.036977
#
#                     ratings_count  text_reviews_count
# bookID                  -0.076820           -0.081289
# average_rating           0.038224            0.033663
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a pandas DataFrame
df = pd.read_csv('books.csv', on_bad_lines='skip')

# Compute the correlation matrix
corr = df.corr()

# Generate a heatmap from the correlation matrix
plt.figure(figsize=(10, 10))
plt.imshow(corr, cmap="RdYlGn", interpolation="nearest")
plt.colorbar()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_24620\3064045464.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# ## Results From Correlation
#
# We Only Observe strong correlation between ratings_count and text_reviews_count

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'BookRatingML.ipynb',
#  'books.csv',
#  'data set without modification.csv',
#  'LICENSE',
#  'Project_Description_ML_2023.docx (2).pdf',
#  'Projet Python retravaillé.xlsx',
#  'Projet Python simulations.xlsx',
#  'README.md',
#  'Summary and to do list.xlsx',
#  '~$Projet Python retravaillé.xlsx',
#  '~$Projet Python simulations.xlsx',
#  '~$Summary and to do list.xlsx']

# %%
pip install openpyxl
# Out:
# ...
#      -------------------------------------- 242.1/242.1 kB 7.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
simulated_data = pd.read_excel('Projet Python simulations.xlsx', sheet_name="Option 1")

# %%
simulated_data.columns
# Out:
# Index(['title', 'Rating_type', 'language_number', 'num_pages', 'ratings_count',
#        'text_reviews_count', 'Season', 'Year', 'Publisher_number',
#        'Main_Author', 'Author_average'],
#       dtype='object')

# %%
corr = simulated_data.corr()
# Generate a heatmap from the correlation matrix
plt.figure(figsize=(10, 10))
plt.imshow(corr, cmap="RdYlGn", interpolation="nearest")
plt.colorbar()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_24620\1650775794.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = simulated_data.corr()

# %%
simulated_data.head()
# Out:
#                                                title  Rating_type  \
# 0                            Twilight (Twilight  #1)            2
# 1                The Hobbit  or There and Back Again            3
# 2                             The Catcher in the Rye            2
# 3               Angels & Demons (Robert Langdon  #1)            2
# 4  Harry Potter and the Prisoner of Azkaban (Harr...            3
#
#    language_number  num_pages  ratings_count  text_reviews_count  Season  \
# 0                1          3              3                   3     3.0
# 1                1          2              3                   3     3.0
# 2                1          2              3                   3     1.0
# 3                1          3              3                   3     2.0
# 4                1          3              3                   3     2.0
#
#    Year  Publisher_number  Main_Author  Author_average
# 0  2006                 1            1             2.0
# ...

# %%
corr
# Out:
#                     Rating_type  language_number  num_pages  ratings_count  \
# Rating_type            1.000000        -0.020164   0.073613       0.072369
# language_number       -0.020164         1.000000  -0.005631      -0.028156
# num_pages              0.073613        -0.005631   1.000000       0.155913
# ratings_count          0.072369        -0.028156   0.155913       1.000000
# text_reviews_count     0.021306        -0.024368   0.152385       0.882087
# Season                -0.008110         0.007003   0.002772       0.037030
# Year                  -0.014777        -0.000111   0.016236       0.044476
# Publisher_number      -0.033381         0.022007  -0.052528      -0.183456
# Main_Author           -0.107184         0.031668  -0.169058      -0.587784
# Author_average         0.706603        -0.039907  -0.016735       0.053389
#
#                     text_reviews_count    Season      Year  Publisher_number  \
# ...
